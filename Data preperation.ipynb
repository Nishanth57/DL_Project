# %%
import os
import shutil
import glob
from tqdm import tqdm

# %%
Raw_DIR= r'C:\Users\nisha\OneDrive\Desktop\proojjjjjj\mrlEyes_2018_01\mrlEyes_2018_01'

# %%
for dirpath, dirname, filenames in os.walk(Raw_DIR):
    for i in tqdm([f for f in filenames if f.endswith('.png')]):
        if i.split('_')[4]=='0':
            shutil.copy(src=dirpath+'/'+i, dst=r'C:\Users\nisha\OneDrive\Desktop\proojjjjjj\Prepared_Data\Close Eyes')
        
        elif i.split('_')[4]=='1':
            shutil.copy(src=dirpath+'/'+i, dst=r'C:\Users\nisha\OneDrive\Desktop\proojjjjjj\Prepared_Data\Open Eyes')
# Out:
# 0it [00:00, ?it/s]
# ...
# 100%|████████████████████████████████████████████████████████████████████████████| 10257/10257 [02:02<00:00, 83.96it/s]
